# %% [markdown]
# # Stage 2. Geocoding Bangkok Neighbourhoods

# %%
from geopy import geocoders
geocoders.options.default_format_string = None
geocoders.options.default_user_agent = 'bkk_explorer'
import folium
from folium.features import DivIcon
import json
import numpy as np

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print('>>> Libraries likely imported')
# Out:
# >>> Libraries likely imported

# %%
# reload data from csv
bkk_khwaengs = pd.read_csv('csv/khwaengs.csv', dtype = 'str')
bkk_khwaengs
# Out:
#     DCode              District       DistrictThai NCode  \
# 0      01           Phra Nakhon             พระนคร    01
# 1      01           Phra Nakhon             พระนคร    02
# 2      01           Phra Nakhon             พระนคร    03
# 3      01           Phra Nakhon             พระนคร    04
# 4      01           Phra Nakhon             พระนคร    05
# 5      01           Phra Nakhon             พระนคร    06
# 6      01           Phra Nakhon             พระนคร    07
# 7      01           Phra Nakhon             พระนคร    08
# 8      01           Phra Nakhon             พระนคร    09
# 9      01           Phra Nakhon             พระนคร    10
# 10     01           Phra Nakhon             พระนคร    11
# 11     01           Phra Nakhon             พระนคร    12
# 12     02                 Dusit              ดุสิต    01
# 13     02                 Dusit              ดุสิต    02
# 14     02                 Dusit              ดุสิต    03
# 15     02                 Dusit              ดุสิต    04
# 16     02                 Dusit              ดุสิต    06
# 17     03             Nong Chok            หนองจอก    01
# 18     03             Nong Chok            หนองจอก    02
# 19     03             Nong Chok            หนองจอก    03
# 20     03             Nong Chok            หนองจอก    04
# 21     03             Nong Chok            หนองจอก    05
# 22     03             Nong Chok            หนองจอก    06
# 23     03             Nong Chok            หนองจอก    07
# 24     03             Nong Chok            หนองจอก    08
# 25     04              Bang Rak             บางรัก    01
# 26     04              Bang Rak             บางรัก    02
# 27     04              Bang Rak             บางรัก    03
# 28     04              Bang Rak             บางรัก    04
# 29     04              Bang Rak             บางรัก    05
# 30     05             Bang Khen             บางเขน    02
# 31     05             Bang Khen             บางเขน    08
# 32     06             Bang Kapi            บางกะปิ    01
# 33     06             Bang Kapi            บางกะปิ    08
# 34     07            Pathum Wan            ปทุมวัน    01
# 35     07            Pathum Wan            ปทุมวัน    02
# 36     07            Pathum Wan            ปทุมวัน    03
# 37     07            Pathum Wan            ปทุมวัน    04
# 38     08  Pom Prap Sattru Phai  ป้อมปราบศัตรูพ่าย    01
# 39     08  Pom Prap Sattru Phai  ป้อมปราบศัตรูพ่าย    02
# 40     08  Pom Prap Sattru Phai  ป้อมปราบศัตรูพ่าย    03
# 41     08  Pom Prap Sattru Phai  ป้อมปราบศัตรูพ่าย    04
# 42     08  Pom Prap Sattru Phai  ป้อมปราบศัตรูพ่าย    05
# 43     09          Phra Khanong            พระโขนง    05
# 44     09          Phra Khanong            พระโขนง    10
# 45     10              Min Buri            มีนบุรี    01
# 46     10              Min Buri            มีนบุรี    02
# 47     11           Lat Krabang          ลาดกระบัง    01
# 48     11           Lat Krabang          ลาดกระบัง    02
# 49     11           Lat Krabang          ลาดกระบัง    03
# 50     11           Lat Krabang          ลาดกระบัง    04
# 51     11           Lat Krabang          ลาดกระบัง    05
# 52     11           Lat Krabang          ลาดกระบัง    06
# 0    Phra Borom Maha Ratchawang     พระบรมมหาราชวัง      NaN       NaN
# 1           Wang Burapha Phirom      วังบูรพาภิรมย์      NaN       NaN
# 2              Wat Ratchabophit          วัดราชบพิธ      NaN       NaN
# 3                    Samran Rat         สำราญราษฎร์      NaN       NaN
# 4              San Chaopho Suea      ศาลเจ้าพ่อเสือ      NaN       NaN
# 5                  Sao Chingcha           เสาชิงช้า      NaN       NaN
# 6                   Bowon Niwet            บวรนิเวศ      NaN       NaN
# 7                     Talat Yot             ตลาดยอด      NaN       NaN
# 8               Chana Songkhram           ชนะสงคราม      NaN       NaN
# 9                 Ban Phan Thom           บ้านพานถม      NaN       NaN
# 10              Bang Khun Phrom          บางขุนพรหม      NaN       NaN
# 11               Wat Sam Phraya         วัดสามพระยา      NaN       NaN
# 12                        Dusit               ดุสิต      NaN       NaN
# 13              Wachiraphayaban          วชิรพยาบาล      NaN       NaN
# 14                Suan Chitlada          สวนจิตรลดา      NaN       NaN
# 15             Si Yaek Maha Nak        สี่แยกมหานาค      NaN       NaN
# 16        Thanon Nakhon Chai Si        ถนนนครไชยศรี      NaN       NaN
# 17                  Krathum Rai          กระทุ่มราย      NaN       NaN
# 18                    Nong Chok             หนองจอก      NaN       NaN
# 19                   Khlong Sip             คลองสิบ      NaN       NaN
# 20              Khlong Sip Song          คลองสิบสอง      NaN       NaN
# 21                    Khok Faet              โคกแฝด      NaN       NaN
# 22                Khu Fang Nuea        คู้ฝั่งเหนือ      NaN       NaN
# 23                 Lam Phak Chi             ลำผักชี      NaN       NaN
# 24                  Lam Toiting          ลำต้อยติ่ง      NaN       NaN
# 25            Maha Phruettharam          มหาพฤฒาราม      NaN       NaN
# 26                       Si Lom                สีลม      NaN       NaN
# 27                   Suriyawong           สุริยวงศ์      NaN       NaN
# 28                     Bang Rak              บางรัก      NaN       NaN
# 29                    Si Phraya            สี่พระยา      NaN       NaN
# 30                    Anusawari          อนุสาวรีย์      NaN       NaN
# 31                    Tha Raeng             ท่าแร้ง      NaN       NaN
# 32                  Khlong Chan            คลองจั่น      NaN       NaN
# 33                      Hua Mak             หัวหมาก      NaN       NaN
# 34                  Rong Mueang            รองเมือง      NaN       NaN
# 35                     Wang Mai             วังใหม่      NaN       NaN
# 36                   Pathum Wan             ปทุมวัน      NaN       NaN
# 37                     Lumphini             ลุมพินี      NaN       NaN
# 38                     Pom Prap            ป้อมปราบ      NaN       NaN
# 39               Wat Thep Sirin      วัดเทพศิรินทร์      NaN       NaN
# 40              Khlong Maha Nak          คลองมหานาค      NaN       NaN
# 41                      Ban Bat            บ้านบาตร      NaN       NaN
# 42                 Wat Sommanat           วัดโสมนัส      NaN       NaN
# 43     Bang Chak (Phra Khanong)    บางจาก (พระโขนง)      NaN       NaN
# 44             Phra Khanong Tai          พระโขนงใต้      NaN       NaN
# 45                     Min Buri             มีนบุรี      NaN       NaN
# 46                    Saen Saep              แสนแสบ      NaN       NaN
# 47                  Lat Krabang           ลาดกระบัง      NaN       NaN
# 48          Khlong Song Ton Nun      คลองสองต้นนุ่น      NaN       NaN
# 49            Khlong Sam Prawet       คลองสามประเวศ      NaN       NaN
# 50                 Lam Pla Thio            ลำปลาทิว      NaN       NaN
# 51                     Thap Yao              ทับยาว      NaN       NaN
# 52                   Khum Thong              ขุมทอง      NaN       NaN
# 53                  Chong Nonsi           ช่องนนทรี      NaN       NaN
# 54              Bang Phongphang           บางโพงพาง      NaN       NaN
# 55                   Chakkrawat           จักรวรรดิ      NaN       NaN
# 56               Samphanthawong         สัมพันธวงศ์      NaN       NaN
# 57                    Talat Noi            ตลาดน้อย      NaN       NaN
# 58                  Sam Sen Nai            สามเสนใน      NaN       NaN
# 59                   Phaya Thai               พญาไท      NaN       NaN
# 60                  Wat Kanlaya          วัดกัลยาณ์      NaN       NaN
# 61                  Hiran Ruchi           หิรัญรูจี      NaN       NaN
# 62                 Bang Yi Ruea          บางยี่เรือ      NaN       NaN
# 63                     Bukkhalo              บุคคโล      NaN       NaN
# 64                   Talat Phlu             ตลาดพลู      NaN       NaN
# 65                  Dao Khanong            ดาวคะนอง      NaN       NaN
# 66                        Samre              สำเหร่      NaN       NaN
# 67                     Wat Arun             วัดอรุณ      NaN       NaN
# 68                 Wat Tha Phra           วัดท่าพระ      NaN       NaN
# 69                  Huai Khwang            ห้วยขวาง      NaN       NaN
# 70                    Bang Kapi             บางกะปิ      NaN       NaN
# 71                  Sam Sen Nok           สามเสนนอก      NaN       NaN
# 72           Somdet Chao Phraya     สมเด็จเจ้าพระยา      NaN       NaN
# 73                   Khlong San             คลองสาน      NaN       NaN
# 74             Bang Lamphu Lang         บางลำภูล่าง      NaN       NaN
# 75               Khlong Ton Sai          คลองต้นไทร      NaN       NaN
# 76             Khlong Chak Phra          คลองชักพระ      NaN       NaN
# 77                  Taling Chan            ตลิ่งชัน      NaN       NaN
# 78                     Chimphli              ฉิมพลี      NaN       NaN
# 79                   Bang Phrom              บางพรม      NaN       NaN
# 80                   Bang Ramat            บางระมาด      NaN       NaN
# 81             Bang Chueak Nang        บางเชือกหนัง      NaN       NaN
# 82                     Siri Rat             ศิริราช      NaN       NaN
# 83                 Ban Chang Lo        บ้านช่างหล่อ      NaN       NaN
# 84                Bang Khun Non          บางขุนนนท์      NaN       NaN
# 85                 Bang Khun Si           บางขุนศรี      NaN       NaN
# 86                 Arun Ammarin        อรุณอมรินทร์      NaN       NaN
# 87                     Tha Kham             ท่าข้าม      NaN       NaN
# 88                    Samae Dam               แสมดำ      NaN       NaN
# 89                      Bang Wa             บางหว้า      NaN       NaN
# 90                    Bang Duan             บางด้วน      NaN       NaN
# 91    Bang Chak (Phasi Charoen)  บางจาก (ภาษีเจริญ)      NaN       NaN
# 92                    Bang Waek              บางแวก      NaN       NaN
# 93                Khlong Khwang            คลองขวาง      NaN       NaN
# 94     Pak Khlong Phasi Charoen    ปากคลองภาษีเจริญ      NaN       NaN
# 95                  Khuha Sawan          คูหาสวรรค์      NaN       NaN
# 96                   Nong Khaem             หนองแขม      NaN       NaN
# 97              Nong Khang Phlu         หนองค้างพลู      NaN       NaN
# 98                   Rat Burana         ราษฎร์บูรณะ      NaN       NaN
# 99                   Bang Pakok            บางปะกอก      NaN       NaN
# 100                  Bang Phlat             บางพลัด      NaN       NaN
# 101                      Bang O              บางอ้อ      NaN       NaN
# 102                  Bang Bamru            บางบำหรุ      NaN       NaN
# 103                Bang Yi Khan           บางยี่ขัน      NaN       NaN
# 104                   Din Daeng              ดินแดง      NaN       NaN
# 105              Ratchadaphisek          รัชดาภิเษก      NaN       NaN
# 106                  Khlong Kum            คลองกุ่ม      NaN       NaN
# 107                     Nawamin            นวมินทร์      NaN       NaN
# 108                   Nuan Chan           นวลจันทร์      NaN       NaN
# 109               Thung Wat Don          ทุ่งวัดดอน      NaN       NaN
# 110                    Yan Nawa             ยานนาวา      NaN       NaN
# 111              Thung Maha Mek          ทุ่งมหาเมฆ      NaN       NaN
# 112                    Bang Sue             บางซื่อ      NaN       NaN
# 113                 Wong Sawang           วงศ์สว่าง      NaN       NaN
# 114                     Lat Yao              ลาดยาว      NaN       NaN
# 115                 Sena Nikhom            เสนานิคม      NaN       NaN
# 116                  Chan Kasem           จันทรเกษม      NaN       NaN
# 117                    Chomphon               จอมพล      NaN       NaN
# 118                   Chatuchak             จตุจักร      NaN       NaN
# 119               Bang Kho Laem           บางคอแหลม      NaN       NaN
# 120             Wat Phraya Krai         วัดพระยาไกร      NaN       NaN
# 121                   Bang Khlo             บางโคล่      NaN       NaN
# 122                      Prawet              ประเวศ      NaN       NaN
# 123                    Nong Bon             หนองบอน      NaN       NaN
# 124                     Dok Mai              ดอกไม้      NaN       NaN
# 125                 Khlong Toei             คลองเตย      NaN       NaN
# 126                  Khlong Tan             คลองตัน      NaN       NaN
# 127                Phra Khanong             พระโขนง      NaN       NaN
# 128                  Suan Luang             สวนหลวง      NaN       NaN
# 129                      On Nut             อ่อนนุช      NaN       NaN
# 130                Phatthanakan            พัฒนาการ      NaN       NaN
# 131             Bang Khun Thian         บางขุนเทียน      NaN       NaN
# 132                    Bang Kho              บางค้อ      NaN       NaN
# 133       Bang Mot (Chom Thong)      บางมด (จอมทอง)      NaN       NaN
# 134                  Chom Thong              จอมทอง      NaN       NaN
# 135                      Si Kan               สีกัน      NaN       NaN
# 136                  Don Mueang            ดอนเมือง      NaN       NaN
# 137                    Sanambin             สนามบิน      NaN       NaN
# 138            Thung Phaya Thai           ทุ่งพญาไท      NaN       NaN
# 139           Thanon Phaya Thai            ถนนพญาไท      NaN       NaN
# 140          Thanon Phetchaburi         ถนนเพชรบุรี      NaN       NaN
# 141                    Makkasan            มักกะสัน      NaN       NaN
# 142                   Lat Phrao            ลาดพร้าว      NaN       NaN
# 143                Chorakhe Bua            จรเข้บัว      NaN       NaN
# 144            Khlong Toei Nuea        คลองเตยเหนือ      NaN       NaN
# 145             Khlong Tan Nuea        คลองตันเหนือ      NaN       NaN
# 146           Phra Khanong Nuea        พระโขนงเหนือ      NaN       NaN
# 147                   Bang Khae               บางแค      NaN       NaN
# 148              Bang Khae Nuea          บางแคเหนือ      NaN       NaN
# 149                   Bang Phai              บางไผ่      NaN       NaN
# 150                    Lak Song             หลักสอง      NaN       NaN
# 151             Thung Song Hong         ทุ่งสองห้อง      NaN       NaN
# 152             Talat Bang Khen          ตลาดบางเขน      NaN       NaN
# 153                     Sai Mai              สายไหม      NaN       NaN
# 154                     O Ngoen              ออเงิน      NaN       NaN
# 155               Khlong Thanon             คลองถนน      NaN       NaN
# 156                 Khan Na Yao            คันนายาว      NaN       NaN
# 157                  Ram Inthra           รามอินทรา      NaN       NaN
# 158                 Saphan Sung            สะพานสูง      NaN       NaN
# 159               Rat Phatthana         ราษฎร์พัฒนา      NaN       NaN
# 160                  Thap Chang             ทับช้าง      NaN       NaN
# 161              Wang Thonglang          วังทองหลาง      NaN       NaN
# 162                 Saphan Song            สะพานสอง      NaN       NaN
# 163        Khlong Chaokhun Sing    คลองเจ้าคุณสิงห์      NaN       NaN
# 164                   Phlapphla             พลับพลา      NaN       NaN
# 165            Sam Wa Tawan Tok        สามวาตะวันตก      NaN       NaN
# 166             Sam Wa Tawan Ok       สามวาตะวันออก      NaN       NaN
# 167                   Bang Chan              บางชัน      NaN       NaN
# 168                Sai Kong Din          ทรายกองดิน      NaN       NaN
# 169            Sai Kong Din Tai       ทรายกองดินใต้      NaN       NaN
# 170                Bang Na Nuea          บางนาเหนือ      NaN       NaN
# 171                 Bang Na Tai            บางนาใต้      NaN       NaN
# 172              Thawi Watthana            ทวีวัฒนา      NaN       NaN
# 173              Sala Thammasop        ศาลาธรรมสพน์      NaN       NaN
# 174       Bang Mot (Thung Khru)     บางมด (ทุ่งครุ)      NaN       NaN
# 175                  Thung Khru             ทุ่งครุ      NaN       NaN
# 176               Bang Bon Nuea         บางบอนเหนือ      NaN       NaN
# 177                Bang Bon Tai           บางบอนใต้      NaN       NaN
# 178           Khlong Bang Phran         คลองบางพราน      NaN       NaN
# 179             Khlong Bang Bon          คลองบางบอน      NaN       NaN

# %% [markdown]
# ## 1. Trying to get khwaeng coordinates with Geopy geocoders

# %% [markdown]
# ### 2.1. Trying all available geocoders from the Geopy package to decide which one to use for the research

# %% [markdown]
# Getting the list of geocoders:

# %%
coders = dir(geocoders)
coders
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocoderNotFound',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'SERVICE_TO_GEOCODER',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'algolia',
#  'arcgis',
#  'azure',
#  'baidu',
#  'banfrance',
#  'base',
#  'bing',
#  'databc',
#  'geocodeearth',
#  'geocodio',
#  'geolake',
#  'geonames',
#  'get_geocoder_for_service',
#  'google',
#  'here',
#  'ignfrance',
#  'mapbox',
#  'mapquest',
#  'maptiler',
#  'nominatim',
#  'opencage',
#  'openmapquest',
#  'options',
#  'pelias',
#  'photon',
#  'pickpoint',
#  'smartystreets',
#  'tomtom',
#  'what3words',
#  'yandex']

# %% [markdown]
# Removing unnecessary items from the list

# %%
coders = coders[:coders.index("Yandex")+1]  # drop everything beyond Yandex
coders
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocoderNotFound',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'SERVICE_TO_GEOCODER',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex']

# %%
def clean_list(list_name, junk):
    for item in junk:
        list_name.remove(item)

# %%
junk = ['GeocoderNotFound', 'SERVICE_TO_GEOCODER']
clean_list(coders, junk)

coders
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex']

# %% [markdown]
# Getting each geocoder try and find one of the more remote neighbourhoods - Khok Faet

# %%
successful_coders = {}
address = 'แขวงโคกแฝด'
for coder in coders:
    print('Trying', coder)
    try:
        geolocator = geocoders.get_geocoder_for_service(coder)
    except: 
        print('Cannot get', coder, 'for service')
        print()
        continue
    try:
        print(geolocator)
        print('Searching:', address)
        location = geolocator().geocode(address)
        print('Found:', location, location.latitude, location.longitude)
        successful_coders[coder] = {'location': location, 'locator': geolocator}
    except:
        print(coder, 'cannot find the location')
        print()
        continue
    print()
# Out:
# Trying AlgoliaPlaces
# Cannot get AlgoliaPlaces for service
#
# Trying ArcGIS
# <class 'geopy.geocoders.arcgis.ArcGIS'>
# Searching: แขวงโคกแฝด
# Found: เขตหนองจอก กุรงเทพมหานคร 13.830434508059682 100.82415605758723
#
# Trying AzureMaps
# Cannot get AzureMaps for service
#
# Trying BANFrance
# <class 'geopy.geocoders.banfrance.BANFrance'>
# Searching: แขวงโคกแฝด
# BANFrance cannot find the location
#
# Trying Baidu
# <class 'geopy.geocoders.baidu.Baidu'>
# Searching: แขวงโคกแฝด
# Baidu cannot find the location
#
# Trying BaiduV3
# <class 'geopy.geocoders.baidu.BaiduV3'>
# Searching: แขวงโคกแฝด
# BaiduV3 cannot find the location
#
# Trying Bing
# <class 'geopy.geocoders.bing.Bing'>
# Searching: แขวงโคกแฝด
# Bing cannot find the location
#
# Trying DataBC
# <class 'geopy.geocoders.databc.DataBC'>
# Searching: แขวงโคกแฝด
# Found: BC 53.913051 -122.7452849
#
# Trying GeoNames
# <class 'geopy.geocoders.geonames.GeoNames'>
# Searching: แขวงโคกแฝด
# GeoNames cannot find the location
#
# Trying GeocodeEarth
# <class 'geopy.geocoders.geocodeearth.GeocodeEarth'>
# Searching: แขวงโคกแฝด
# GeocodeEarth cannot find the location
#
# Trying Geocodio
# <class 'geopy.geocoders.geocodio.Geocodio'>
# Searching: แขวงโคกแฝด
# Geocodio cannot find the location
#
# Trying Geolake
# <class 'geopy.geocoders.geolake.Geolake'>
# Searching: แขวงโคกแฝด
# Geolake cannot find the location
#
# Trying GoogleV3
# <class 'geopy.geocoders.google.GoogleV3'>
# Searching: แขวงโคกแฝด
# GoogleV3 cannot find the location
#
# Trying Here
# <class 'geopy.geocoders.here.Here'>
# Searching: แขวงโคกแฝด
# Here cannot find the location
#
# Trying HereV7
# <class 'geopy.geocoders.here.HereV7'>
# Searching: แขวงโคกแฝด
# HereV7 cannot find the location
#
# Trying IGNFrance
# <class 'geopy.geocoders.ignfrance.IGNFrance'>
# Searching: แขวงโคกแฝด
# IGNFrance cannot find the location
#
# Trying LiveAddress
# <class 'geopy.geocoders.smartystreets.LiveAddress'>
# Searching: แขวงโคกแฝด
# LiveAddress cannot find the location
#
# Trying MapBox
# <class 'geopy.geocoders.mapbox.MapBox'>
# Searching: แขวงโคกแฝด
# MapBox cannot find the location
#
# Trying MapQuest
# <class 'geopy.geocoders.mapquest.MapQuest'>
# Searching: แขวงโคกแฝด
# MapQuest cannot find the location
#
# Trying MapTiler
# <class 'geopy.geocoders.maptiler.MapTiler'>
# Searching: แขวงโคกแฝด
# MapTiler cannot find the location
#
# Trying Nominatim
# <class 'geopy.geocoders.nominatim.Nominatim'>
# Searching: แขวงโคกแฝด
# Found: แขวงโคกแฝด, เขตหนองจอก, กรุงเทพมหานคร, 10530, ประเทศไทย 13.8537368 100.828743
#
# Trying OpenCage
# <class 'geopy.geocoders.opencage.OpenCage'>
# Searching: แขวงโคกแฝด
# OpenCage cannot find the location
#
# Trying OpenMapQuest
# <class 'geopy.geocoders.openmapquest.OpenMapQuest'>
# Searching: แขวงโคกแฝด
# OpenMapQuest cannot find the location
#
# Trying Pelias
# <class 'geopy.geocoders.pelias.Pelias'>
# Searching: แขวงโคกแฝด
# Pelias cannot find the location
#
# Trying Photon
# <class 'geopy.geocoders.photon.Photon'>
# Searching: แขวงโคกแฝด
# Photon cannot find the location
#
# Trying PickPoint
# <class 'geopy.geocoders.pickpoint.PickPoint'>
# Searching: แขวงโคกแฝด
# PickPoint cannot find the location
#
# Trying TomTom
# <class 'geopy.geocoders.tomtom.TomTom'>
# Searching: แขวงโคกแฝด
# TomTom cannot find the location
#
# Trying What3Words
# <class 'geopy.geocoders.what3words.What3Words'>
# Searching: แขวงโคกแฝด
# What3Words cannot find the location
#
# Trying What3WordsV3
# <class 'geopy.geocoders.what3words.What3WordsV3'>
# Searching: แขวงโคกแฝด
# What3WordsV3 cannot find the location
#
# Trying Yandex
# <class 'geopy.geocoders.yandex.Yandex'>
# Searching: แขวงโคกแฝด
# Yandex cannot find the location

# %% [markdown]
# ##### The only geocoders that can find **โคกแฝด** neighbourhood in Bangkok with no intricate setup procedure are:

# %%
for k, v in successful_coders.items():
    print(k, ":")
    print('\t', v)
# Out:
# ArcGIS :
# 	 {'location': Location(เขตหนองจอก กุรงเทพมหานคร, (13.830434508059682, 100.82415605758723, 0.0)), 'locator': <class 'geopy.geocoders.arcgis.ArcGIS'>}
# DataBC :
# 	 {'location': Location(BC, (53.913051, -122.7452849, 0.0)), 'locator': <class 'geopy.geocoders.databc.DataBC'>}
# Nominatim :
# 	 {'location': Location(แขวงโคกแฝด, เขตหนองจอก, กรุงเทพมหานคร, 10530, ประเทศไทย, (13.8537368, 100.828743, 0.0)), 'locator': <class 'geopy.geocoders.nominatim.Nominatim'>}

# %% [markdown]
# and the location returned by DataBC is definitely way off with longitude value of -122.7452849.

# %%
successful_coders.pop('DataBC')
# Out:
# {'location': Location(BC, (53.913051, -122.7452849, 0.0)),
#  'locator': geopy.geocoders.databc.DataBC}

# %% [markdown]
# Visualizing the other two results on map:

# %%
center_latitude = sum(value['location'].latitude for value in successful_coders.values())/len(successful_coders)
center_longitude = sum(value['location'].longitude for value in successful_coders.values())/len(successful_coders)

center_latitude, center_longitude
# Out:
# (13.842085654029841, 100.82644952879362)

# %%
map_khokfaet = folium.Map(location=[center_latitude, center_longitude], zoom_start=13)

for coder, value in successful_coders.items():
    location = (value['location'].latitude, value['location'].longitude)
    # add marker to map
    folium.CircleMarker(
            location,
            radius=5,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_khokfaet)  
    # add market label to map
    folium.map.Marker(
            location,
            icon=DivIcon(
                # icon_size=(30,30),
                icon_anchor=(-2,-2),
                html=f'<div style="font-size: 14pt">{coder}</div>')).add_to(map_khokfaet)

map_khokfaet
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2eeb06953ca3ddf27cab6740c277b316 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2eeb06953ca3ddf27cab6740c277b316&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2eeb06953ca3ddf27cab6740c277b316 = L.map(
#                 &quot;map_2eeb06953ca3ddf27cab6740c277b316&quot;,
#                 {
#                     center: [13.842085654029841, 100.82644952879362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27f31ecc398dd8eb18e9a0006795848d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var circle_marker_4e2b30106b4da7135b2a66728fc97ae6 = L.circleMarker(
#                 [13.830434508059682, 100.82415605758723],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var marker_924fc55ba482d95fe1184afa3ee32717 = L.marker(
#                 [13.830434508059682, 100.82415605758723],
#                 {}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var div_icon_556cdc09002eaf3df96ef51821a49f55 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt\&quot;\u003eArcGIS\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [-2, -2]});
#             marker_924fc55ba482d95fe1184afa3ee32717.setIcon(div_icon_556cdc09002eaf3df96ef51821a49f55);
#
#
#             var circle_marker_7a3ac29cfcce127fa152ba6d8a569f94 = L.circleMarker(
#                 [13.8537368, 100.828743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var marker_b062452245ee6765a9e78945b5ffea0e = L.marker(
#                 [13.8537368, 100.828743],
#                 {}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var div_icon_a471e56ac8b24c283f272c64bacee36b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt\&quot;\u003eNominatim\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [-2, -2]});
#             marker_b062452245ee6765a9e78945b5ffea0e.setIcon(div_icon_a471e56ac8b24c283f272c64bacee36b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Location returned by ArcGIS appears to be roughly at the spacial center of the khwaeng, while that returned by Nominatim is near the boundary yet in the most built-up area on the main thoroughfare.

# %% [markdown]
# ### 2.2. Trying both geocoders to get coordinates for each of 180 neighbourhoods

# %%
def get_geolocator_by_name(name):
    return successful_coders[name]['locator']

# %%
def put_location_on_map(folium_map, locator_name, address):
    locator = get_geolocator_by_name(locator_name)
    location = locator().geocode(address)
    location = (location.latitude, location.longitude)
    color = successful_coders[locator_name]['color']
    # add marker to map
    folium.CircleMarker(
            location,
            radius=3,
            tooltip = address,
            popup=locator_name,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7,
            parse_html=False).add_to(folium_map)

# %%
successful_coders['ArcGIS']['color'] = 'green'
successful_coders['Nominatim']['color'] = 'blue'
[(coder, successful_coders[coder]['color']) for coder in successful_coders]
# Out:
# [('ArcGIS', 'green'), ('Nominatim', 'blue')]

# %% [markdown]
# #### 2.1.1. Trying on just one khwaeng first

# %%
locator = get_geolocator_by_name('ArcGIS')
center = locator().geocode("กุรงเทพมหานคร")
center
# Out:
# Location(กรุงเทพมหานคร พระนคร กรุงเทพมหานคร, (13.753360000000043, 100.50483000000008, 0.0))

# %%
center.raw
# Out:
# {'address': 'กรุงเทพมหานคร พระนคร กรุงเทพมหานคร',
#  'location': {'x': 100.50483000000008, 'y': 13.753360000000043},
#  'score': 100,
#  'attributes': {},
#  'extent': {'xmin': 100.49483000000008,
#   'ymin': 13.743360000000044,
#   'xmax': 100.51483000000009,
#   'ymax': 13.763360000000043}}

# %%
bkk_map = folium.Map(location=[center.latitude, center.longitude], zoom_start=11)

for coder in successful_coders:
    put_location_on_map(bkk_map, coder, address)
    
bkk_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd6be79a2640cfede87391f80d5fddb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd6be79a2640cfede87391f80d5fddb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd6be79a2640cfede87391f80d5fddb8 = L.map(
#                 &quot;map_fd6be79a2640cfede87391f80d5fddb8&quot;,
#                 {
#                     center: [13.753360000000043, 100.50483000000008],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d61389feb7b9ab18e8ef492bd26474cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd6be79a2640cfede87391f80d5fddb8);
#
#
#             var circle_marker_de1537932a6bac0ff12f5530a3b7de3f = L.circleMarker(
#                 [13.830434508059682, 100.82415605758723],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd6be79a2640cfede87391f80d5fddb8);
#
#
#         var popup_50243846ee1933ab40ba978188ccd906 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbc43093d9c3e1c551f6f73d74312274 = $(`&lt;div id=&quot;html_cbc43093d9c3e1c551f6f73d74312274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ArcGIS&lt;/div&gt;`)[0];
#                 popup_50243846ee1933ab40ba978188ccd906.setContent(html_cbc43093d9c3e1c551f6f73d74312274);
#
#
#
#         circle_marker_de1537932a6bac0ff12f5530a3b7de3f.bindPopup(popup_50243846ee1933ab40ba978188ccd906)
#         ;
#
#
#
#
#             circle_marker_de1537932a6bac0ff12f5530a3b7de3f.bindTooltip(
#                 `&lt;div&gt;
#                      แขวงโคกแฝด
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c28cd80799d09d1d9ea166eeb54172e2 = L.circleMarker(
#                 [13.8537368, 100.828743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd6be79a2640cfede87391f80d5fddb8);
#
#
#         var popup_0d99c2acaf1850e57f7ead6563eacab7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_331540c1ae20980f196172d5cd901942 = $(`&lt;div id=&quot;html_331540c1ae20980f196172d5cd901942&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nominatim&lt;/div&gt;`)[0];
#                 popup_0d99c2acaf1850e57f7ead6563eacab7.setContent(html_331540c1ae20980f196172d5cd901942);
#
#
#
#         circle_marker_c28cd80799d09d1d9ea166eeb54172e2.bindPopup(popup_0d99c2acaf1850e57f7ead6563eacab7)
#         ;
#
#
#
#
#             circle_marker_c28cd80799d09d1d9ea166eeb54172e2.bindTooltip(
#                 `&lt;div&gt;
#                      แขวงโคกแฝด
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bkk_map_all = folium.Map(location=[center.latitude, center.longitude], zoom_start=11)

for khwaeng in bkk_khwaengs.NeighbourhoodThai:
    address = 'แขวง' + khwaeng
    for coder in successful_coders:
        put_location_on_map(bkk_map_all, coder, address)
        
bkk_map_all
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f1b77ac7c41e3a8e7c88c85428f958a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f1b77ac7c41e3a8e7c88c85428f958a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f1b77ac7c41e3a8e7c88c85428f958a = L.map(
#                 &quot;map_5f1b77ac7c41e3a8e7c88c85428f958a&quot;,
#                 {
#                     center: [13.753360000000043, 100.50483000000008],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e97c25f1a392d70af331c3f790515935 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f1b77ac7c41e3a8e7c88c85428f958a);
#
#
#             var circle_marker_4b92a98efbdf45f0d755b9f125759801 = L.circleMarker(
#                 [13.752547700906803, 100.48842282504893],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f1b77ac7c41e3a8e7c88c85428f958a);
#
#
#         var popup_0ef3a9c02cba9fb3be6bc730642b5143 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_620180f14c08496b5e7707e20202d0c3 = $(`&lt;div id=&quot;html_620180f14c08496b5e7707e20202d0c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ArcGIS&lt;/div&gt;`)[0];
#                 popup_0ef3a9c02cba9fb3be6bc730642b5143.setContent(html_620180f14c08496b5e7707e20202d0c3);
#
#
#
#         circle_marker_4b92a98efbdf45f0d755b9f125759801.bindPopup(popup_0ef3a9c02cba9fb3be6bc730642b5143)
#         ;
#
#
#
#
#             circle_marker_4b92a98efbdf45f0d755b9f125759801.bindTooltip(
#                 `&lt;div&gt;
#                      แขวงพระบรมมหาราชวัง
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b81505b096493f66045b77e5bc57eaa9 = L.circleMarker(
#                 [13.7499943, 100.4917502],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f1b77ac7c41e3a8e7c88c85428f958a);
#
#
#         var popup_1320ba8b71e47491a2b1c3fcdcc10b8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70c9f58fbde6a9aa3e2e2457cd8f5cdf = $(`&lt;div id=&quot;html_70c9f58fbde6a9aa3e2e2457cd8f5cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nominatim&lt;/div&gt;`)[0];
#                 popup_1320ba8b71e47491a2b1c3fcdcc10b8c.setContent(html_70c9f58fbde6a9aa3e2e2457cd8f5cdf);
#
#
#
#         circle_marker_b81505b096493f66045b77e5bc57eaa9.bindPopup(popup_1320ba8b71e47491a2b1c3fcdcc10b8c)
#         ;
#
#
#
#
#             circle_marker_b81505b096493f66045b77e5bc57eaa9.bindTooltip(
#                 `&lt;div&gt;
#                      แขวงพระบรมมหาราชวัง
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_aa69d0a508bf6559667f906ed8c90135 = L.circleMarker(
#                 [13.744277452840834, 100.50017205376258],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5f1b77ac7c41e3a8e7c88c85428f958a);
#
#
#         var popup_3f6a0ba4515a2fada12c631c4d24f084 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91de82d64040cf6d168fa2c47fcfbd96 = $(`&lt;div id=&quot;html_91de82d64040cf6d168fa2c47fcfbd96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ArcGIS&lt;/div&gt;`)[0];
#                 popup_3f6a0

# %% [markdown]
# Significant and interesting discrepancies can be observed. Take a look at what data each geolocator operates.

# %%
for coder in successful_coders:
    geolocator = get_geolocator_by_name(coder)
    loc = geolocator().geocode(address)
    print(coder + ':')
    print(json.dumps(loc.raw, ensure_ascii=False, indent=2))
    print()
# Out:
# ArcGIS:
# {
#   "address": "เขตบางบอน กุรงเทพมหานคร",
#   "location": {
#     "x": 100.42758617288092,
#     "y": 13.671001120449034
#   },
#   "score": 100,
#   "attributes": {},
#   "extent": {
#     "xmin": 100.40758617288093,
#     "ymin": 13.651001120449035,
#     "xmax": 100.44758617288092,
#     "ymax": 13.691001120449034
#   }
# }
#
# Nominatim:
# {
#   "place_id": 309702371,
#   "licence": "Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#   "osm_type": "relation",
#   "osm_id": 11347183,
#   "boundingbox": [
#     "13.6477986",
#     "13.6848944",
#     "100.4052463",
#     "100.446863"
#   ],
#   "lat": "13.6706951",
#   "lon": "100.4273772",
#   "display_name": "แขวงคลองบางบอน, เขตบางบอน, กรุงเทพมหานคร, 10150, ประเทศไทย",
#   "class": "boundary",
#   "type": "administrative",
#   "importance": 0.4600099999999999,
#   "icon": "https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png"
# }

# %% [markdown]
# **Do they always use geometrical center of the bounding box as each of them sees it?**

# %%
locator = get_geolocator_by_name('ArcGIS')

for khwaeng in bkk_khwaengs.NeighbourhoodThai:
    address = 'แขวง' + khwaeng
    location = locator().geocode(address)
    point = (location.raw['location']['x'], location.raw['location']['y'])
    box = location.raw['extent']
    mean_point = (box['xmin'] + box['xmax']) / 2, (box['ymin'] + box['ymax']) / 2
    print(address, point, mean_point, point == mean_point)
# Out:
# แขวงพระบรมมหาราชวัง (100.48842282504893, 13.752547700906803) (100.48842282504893, 13.752547700906803) True
# แขวงวังบูรพาภิรมย์ (100.50017205376258, 13.744277452840834) (100.50017205376258, 13.744277452840834) True
# แขวงวัดราชบพิธ (100.50023591999474, 13.749502618836573) (100.50023591999474, 13.749502618836573) True
# แขวงสำราญราษฎร์ (100.50401726674164, 13.752578212017738) (100.50401726674164, 13.752578212017738) True
# แขวงศาลเจ้าพ่อเสือ (100.49719802795067, 13.75461467642117) (100.49719802795067, 13.75461467642117) True
# แขวงเสาชิงช้า (100.50107370204046, 13.753375328915581) (100.50107370204046, 13.753375328915581) True
# แขวงบวรนิเวศ (100.50278173524993, 13.756087935777146) (100.50278173524993, 13.756087935777146) True
# แขวงตลาดยอด (100.4986461872154, 13.761072562898448) (100.4986461872154, 13.761072562898448) True
# แขวงชนะสงคราม (100.49600999763169, 13.763591271055077) (100.49600999763169, 13.763591271055077) True
# แขวงบางชัน (13.8190882, 100.6990743) (13.840111, 100.7002593) delta:  -0.02102 -0.00118
# แขวงทรายกองดิน (13.8452158, 100.7434809) (13.8488654, 100.7472176) delta:  -0.00365 -0.00374
# แขวงทรายกองดินใต้ (13.8370903, 100.7700884) (13.8510285, 100.7726938) delta:  -0.01394 -0.00261
# แขวงบางนาเหนือ (13.6751361, 100.6174063) (13.6745304, 100.6198241) delta:  0.00061 -0.00242
# แขวงบางนาใต้ (13.669538, 100.6052291) (13.6624083, 100.6159053) delta:  0.00713 -0.01068
# แขวงทวีวัฒนา (13.7664855, 100.3455967) (13.7582341, 100.368378) delta:  0.00825 -0.02278
# แขวงศาลาธรรมสพน์ (13.7978235, 100.3713513) (13.7821331, 100.3694596) delta:  0.01569 0.00189
# แขวงบางมด (ทุ่งครุ) (13.6512415, 100.4741871) (13.6485, 100.4940597) delta:  0.00274 -0.01987
# แขวงทุ่งครุ (13.6304099, 100.504024) (13.6210389, 100.4965274) delta:  0.00937 0.0075
# แขวงบางบอนเหนือ (13.6556202, 100.3848696) (13.6546109, 100.3758555) delta:  0.00101 0.00901
# แขวงบางบอนใต้ (13.6461745, 100.3880238) (13.6419227, 100.3868892) delta:  0.00425 0.00113
# แขวงคลองบางพราน (13.6778152, 100.4254139) (13.6784611, 100.425481) delta:  -0.00065 -7e-05
# แขวงคลองบางบอน (13.6706951, 100.4273772) (13.6663465, 100.4260546) delta:  0.00435 0.00132

# %% [markdown]
# - No, Nominatim probably does not, using a different more complex definition, or there might be some kind of accumulated error in their calculations.

# %%
khokFaet = geolocator().geocode('แขวงโคกแฝด')
khokFaet.raw
# Out:
# {'place_id': 309574721,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 11547831,
#  'boundingbox': ['13.8079166', '13.8575206', '100.7990805', '100.8557689'],
#  'lat': '13.8537368',
#  'lon': '100.828743',
#  'display_name': 'แขวงโคกแฝด, เขตหนองจอก, กรุงเทพมหานคร, 10530, ประเทศไทย',
#  'class': 'boundary',
#  'type': 'administrative',
#  'importance': 0.4600099999999999,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}

# %%
box = [float(value) for value in khokFaet.raw['boundingbox']]

south = box[0]
north = box[1]
west = box[2]
east = box[3]

corners = [
    (north, west), 
    (north, east),
    (south, east),
    (south, west),
    (north, west), 
]

corners
# Out:
# [(13.8575206, 100.7990805),
#  (13.8575206, 100.8557689),
#  (13.8079166, 100.8557689),
#  (13.8079166, 100.7990805),
#  (13.8575206, 100.7990805)]

# %%
folium.PolyLine(corners, tooltip="Nominatim", color='blue').add_to(map_khokfaet)

map_khokfaet
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2eeb06953ca3ddf27cab6740c277b316 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2eeb06953ca3ddf27cab6740c277b316&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2eeb06953ca3ddf27cab6740c277b316 = L.map(
#                 &quot;map_2eeb06953ca3ddf27cab6740c277b316&quot;,
#                 {
#                     center: [13.842085654029841, 100.82644952879362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27f31ecc398dd8eb18e9a0006795848d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var circle_marker_4e2b30106b4da7135b2a66728fc97ae6 = L.circleMarker(
#                 [13.830434508059682, 100.82415605758723],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var marker_924fc55ba482d95fe1184afa3ee32717 = L.marker(
#                 [13.830434508059682, 100.82415605758723],
#                 {}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var div_icon_556cdc09002eaf3df96ef51821a49f55 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt\&quot;\u003eArcGIS\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [-2, -2]});
#             marker_924fc55ba482d95fe1184afa3ee32717.setIcon(div_icon_556cdc09002eaf3df96ef51821a49f55);
#
#
#             var circle_marker_7a3ac29cfcce127fa152ba6d8a569f94 = L.circleMarker(
#                 [13.8537368, 100.828743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var marker_b062452245ee6765a9e78945b5ffea0e = L.marker(
#                 [13.8537368, 100.828743],
#                 {}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             var div_icon_a471e56ac8b24c283f272c64bacee36b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt\&quot;\u003eNominatim\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [-2, -2]});
#             marker_b062452245ee6765a9e78945b5ffea0e.setIcon(div_icon_a471e56ac8b24c283f272c64bacee36b);
#
#
#             var poly_line_cd3bbf7abf7fe642a3b914523d1c8dc5 = L.polyline(
#                 [[13.8575206, 100.7990805], [13.8575206, 100.8557689], [13.8079166, 100.8557689], [13.8079166, 100.7990805]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eeb06953ca3ddf27cab6740c277b316);
#
#
#             poly_line_cd3bbf7abf7fe642a3b914523d1c8dc5.bindTooltip(
#                 `&lt;div&gt;
#                      Nominatim
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_d0e4ea18b023c59d83e16f387eef694e = L.polyline(
#                 [[13.8575206, 100.7990805], [13.8575206, 100.8557689], [13.8079166, 100.8557689], [13.8079166, 100.7990805], [13.8575206, 100.7990805]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;:

# %% [markdown]
# #### 2.1.2. Geocoding all neighbourhoods

# %%
bkk_khwaengs.columns
# Out:
# Index(['DCode', 'District', 'DistrictThai', 'NCode', 'Neighbourhood',
#        'NeighbourhoodThai', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
lats = list() # creating an empty list to store lattitudes
longs = list() # and longitudes
for i, row in bkk_khwaengs.iterrows() :
    location = geolocator.geocode(row['NeighbourhoodThai'])
    lats.append(location.latitude)
    longs.append(location.longitude)
    print(i, location, location.latitude, location.longitude)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8268\3670992924.py in <module>
#       2 longs = list() # and longitudes
#       3 for i, row in bkk_khwaengs.iterrows() :
# ----> 4     location = geolocator.geocode(row['NeighbourhoodThai'])
#       5     lats.append(location.latitude)
#       6     longs.append(location.longitude)
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %% [markdown]
# and adding each neighbourhood coordinates to the dataframe in respective columns:

# %%
bkk_khwaengs.columns

# %%
bkk_khwaengs['Latitude'] = lats
bkk_khwaengs['Longitude'] = longs
bkk_khwaengs

# %%
bkk_khwaengs.describe(include='all')

# %%
bkk_khwaengs.dtypes

# %%
bkk_khwaengs.to_csv('khwaengs_geocoded2.csv', index = False)

# %% [markdown]
# #### 2.1.3. Visualizing bangkok neighbourhoods on Folium map

# %%
# create map of Bangkok using latitude and longitude values
latitude = bkk_khwaengs.Latitude.mean() + 0.01
longitude = bkk_khwaengs.Longitude.mean() + 0.06
map_bangkok = folium.Map(location = (latitude, longitude), width = 900, zoom_start=11)

# add markers to map
for lat, lng, neighbourhood in zip(bkk_khwaengs['Latitude'], bkk_khwaengs['Longitude'], bkk_khwaengs['Neighbourhood']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bangkok)  
    
map_bangkok
